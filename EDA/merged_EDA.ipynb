# %% [markdown]
# # Merged Dataset
# * has the combination of user_log and user_info
# * allows for the correlation of age and gender into the dataset without constantly referencing back and forth

# %%
import numpy as np
import pandas as pd

import seaborn as sns

# %%
merged = pd.read_csv('../data_format1/use_data/merged_dataset.csv')

# %%
print(merged.head())
# Out:
#    user_id  item_id  cat_id  seller_id  brand_id  time_stamp  action_type  \
# 0   149002      282     885       3791    1500.0        1111            0
# 1   149002      282     885       3791    1500.0        1107            0
# 2   109881      230     629          1    1662.0         820            0
# 3   109881      230     629          1    1662.0         820            0
# 4   109881      230     629          1    1662.0         820            0
#
#    age_range  gender
# 0        5.0     2.0
# 1        5.0     2.0
# 2        4.0     0.0
# 3        4.0     0.0
# 4        4.0     0.0

# %%
sns.distplot(merged['age_range'], kde=True, hist=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_14988\2983451740.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(merged['age_range'], kde=True, hist=True)
# <AxesSubplot:xlabel='age_range', ylabel='Density'>

# %%
sns.distplot(merged['gender'], kde=True, hist=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_14988\20482699.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(merged['gender'], kde=True, hist=True)
# <AxesSubplot:xlabel='gender', ylabel='Density'>
