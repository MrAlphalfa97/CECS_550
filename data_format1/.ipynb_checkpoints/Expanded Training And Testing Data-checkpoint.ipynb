# %%
#!pip install shap
#!pip install sklearn
import pandas as pd
import numpy as np
import shap
import sklearn
import seaborn as sn
import matplotlib.pyplot as plt
from numpy.linalg import eig
from sklearn.decomposition import PCA

# %%
df_testing = pd.read_csv("./use_data/merged_dataset.csv")
df_testing['prob'] = np.nan
df_testing
# Out:
#       user_id  item_id  cat_id  seller_id  brand_id  time_stamp  action_type  \
# 0      149002      282     885       3791    1500.0        1111            0
# 1      149002      282     885       3791    1500.0        1107            0
# 2      109881      230     629          1    1662.0         820            0
# 3      109881      230     629          1    1662.0         820            0
# 4      109881      230     629          1    1662.0         820            0
# ...       ...      ...     ...        ...       ...         ...          ...
# 6544    73105      259     614        637    2603.0        1111            0
# 6545   403421      175    1181       4760     247.0        1111            0
# 6546   116738      186     267       1200    2276.0        1110            0
# 6547   116738      186     267       1200    2276.0        1101            0
# 6548   124951      184     656        145    3462.0        1111            0
#
#       age_range  gender  prob
# 0           5.0     2.0   NaN
# 1           5.0     2.0   NaN
# 2           4.0     0.0   NaN
# 3           4.0     0.0   NaN
# 4           4.0     0.0   NaN
# ...         ...     ...   ...
# 6544        2.0     0.0   NaN
# 6545        3.0     1.0   NaN
# 6546        2.0     1.0   NaN
# 6547        2.0     1.0   NaN
# 6548        0.0     0.0   NaN
#
# [6549 rows x 10 columns]

# %%
df_training = pd.read_csv("./use_data/merged_dataset.csv")
df_training['label'] = -1
df_training
# Out:
#       user_id  item_id  cat_id  seller_id  brand_id  time_stamp  action_type  \
# 0      149002      282     885       3791    1500.0        1111            0
# 1      149002      282     885       3791    1500.0        1107            0
# 2      109881      230     629          1    1662.0         820            0
# 3      109881      230     629          1    1662.0         820            0
# 4      109881      230     629          1    1662.0         820            0
# ...       ...      ...     ...        ...       ...         ...          ...
# 6544    73105      259     614        637    2603.0        1111            0
# 6545   403421      175    1181       4760     247.0        1111            0
# 6546   116738      186     267       1200    2276.0        1110            0
# 6547   116738      186     267       1200    2276.0        1101            0
# 6548   124951      184     656        145    3462.0        1111            0
#
#       age_range  gender  label
# 0           5.0     2.0     -1
# 1           5.0     2.0     -1
# 2           4.0     0.0     -1
# 3           4.0     0.0     -1
# 4           4.0     0.0     -1
# ...         ...     ...    ...
# 6544        2.0     0.0     -1
# 6545        3.0     1.0     -1
# 6546        2.0     1.0     -1
# 6547        2.0     1.0     -1
# 6548        0.0     0.0     -1
#
# [6549 rows x 10 columns]

# %%
df_labels = pd.read_csv("./use_data/train_format1[161-320].csv")
df_labels
# Out:
#      user_id  merchant_id  label
# 0     108672         4760      0
# 1       6018          145      0
# 2     134532         3323      1
# 3     340104         3263      0
# 4     367500         4405      0
# ..       ...          ...    ...
# 164   327782         2277      0
# 165     8552         2277      0
# 166   177770         3323      1
# 167   125558         3323      0
# 168   276857         3323      0
#
# [169 rows x 3 columns]

# %%
for index,row in df_training.iterrows():
    for index2,row2 in df_labels.iterrows():
        if((row['user_id'] == row2['user_id']) & (row['seller_id'] == row2['merchant_id'])):
            df_training.at[index, 'label'] = row2['label']

# %%
df_training = df_training[df_training['label'] != -1]
df_training
# Out:
#       user_id  item_id  cat_id  seller_id  brand_id  time_stamp  action_type  \
# 31     379824      198     656        145    3462.0        1111            0
# 32     379824      198     656        145    3462.0        1111            0
# 33     379824      198     656        145    3462.0        1111            2
# 34     379824      198     656        145    3462.0        1110            0
# 35     379824      198     656        145    3462.0        1110            0
# ...       ...      ...     ...        ...       ...         ...          ...
# 6463   122632      175    1181       4760     247.0        1109            0
# 6464   122632      175    1181       4760     247.0        1108            0
# 6465   122632      175    1181       4760     247.0        1108            0
# 6508    95362      253     962       3263     626.0        1111            0
# 6515    99823      175    1181       4760     247.0        1110            0
#
#       age_range  gender  label
# 31          5.0     1.0      0
# 32          5.0     1.0      0
# 33          5.0     1.0      0
# 34          5.0     1.0      0
# 35          5.0     1.0      0
# ...         ...     ...    ...
# 6463        3.0     0.0      0
# 6464        3.0     0.0      0
# 6465        3.0     0.0      0
# 6508        0.0     0.0      0
# 6515        2.0     0.0      0
#
# [385 rows x 10 columns]

# %%
expanded_testing = df_testing
expanded_training = df_training
expanded_testing.to_csv(index=False, header=True)
expanded_training.to_csv(index=False, header=True)
# Out:
# 'user_id,item_id,cat_id,seller_id,brand_id,time_stamp,action_type,age_range,gender,label\r\n379824,198,656,145,3462.0,1111,0,5.0,1.0,0\r\n379824,198,656,145,3462.0,1111,0,5.0,1.0,0\r\n379824,198,656,145,3462.0,1111,2,5.0,1.0,0\r\n379824,198,656,145,3462.0,1110,0,5.0,1.0,0\r\n379824,198,656,145,3462.0,1110,0,5.0,1.0,0\r\n379824,198,656,145,3462.0,1110,0,5.0,1.0,0\r\n141307,175,1181,4760,247.0,1107,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1107,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1107,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,2,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,0,4.0,1.0,0\r\n141307,175,1181,4760,247.0,1111,0,4.0,1.0,0\r\n252255,175,1181,4760,247.0,1111,0,3.0,1.0,0\r\n309566,175,1181,4760,247.0,1111,2,5.0,0.0,0\r\n206032,281,1130,246,5380.0,1108,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1108,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1104,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1104,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,2,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1107,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,2,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1103,3,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1109,0,4.0,0.0,0\r\n206032,281,1130,246,5380.0,1105,0,4.0,0.0,0\r\n182119,279,898,3323,683.0,1111,0,4.0,1.0,0\r\n182119,279,898,3323,683.0,1110,0,4.0,1.0,0\r\n68225,279,898,3323,683.0,1108,0,5.0,1.0,1\r\n109919,198,656,145,3462.0,1105,0,4.0,0.0,0\r\n342023,190,664,1131,2350.0,1108,0,3.0,0.0,0\r\n342023,190,664,1131,2350.0,1108,0,3.0,0.0,0\r\n287829,175,1181,4760,247.0,1111,0,3.0,0.0,0\r\n255960,279,898,3323,683.0,1111,0,3.0,0.0,0\r\n380420,190,664,1131,2350.0,1105,0,3.0,0.0,0\r\n176150,175,1181,4760,247.0,1111,0,3.0,1.0,0\r\n176150,175,1181,4760,247.0,1111,0,3.0,1.0,0\r\n407671,219,349,1943,6208.0,1111,0,6.0,0.0,0\r\n407671,219,349,1943,6208.0,1111,2,6.0,0.0,0\r\n407671,219,349,1943,6208.0,1111,0,6.0,0.0,0\r\n407671,219,349,1943,6208.0,1109,3,6.0,0.0,0\r\n407671,219,349,1943,6208.0,1109,0,6.0,0.0,0\r\n407671,219,349,1943,6208.0,1109,0,6.0,0.0,0\r\n388332,285,1577,630,1905.0,520,0,5.0,0.0,0\r\n244552,278,1075,1210,6230.0,1111,2,2.0,1.0,0\r\n244552,278,1075,1210,6230.0,1111,0,2.0,1.0,0\r\n46507,224,614,4955,7924.0,1111,0,3.0,0.0,0\r\n46507,224,614,4955,7924.0,1111,0,3.0,0.0,0\r\n46507,224,614,4955,7924.0,1111,2,3.0,0.0,0\r\n191162,184,656,145,3462.0,1111,0,0.0,0.0,0\r\n191162,184,656,145,3462.0,1111,2,0.0,0.0,0\r\n174308,175,1181,4760,247.0,1111,0,0.0,1.0,0\r\n174308,175,1181,4760,247.0,1111,0,0.0,1.0,0\r\n174308,175,1181,4760,247.0,1111,2,0.0,1.0,0\r\n174308,175,1181,4760,247.0,1111,0,0.0,1.0,0\r\n134532,279,898,3323,683.0,1111,0,0.0,1.0,1\r\n355159,279,898,3323,683.0,1111,0,0.0,0.0,0\r\n62942,312,602,4129,5491.0,1103,0,2.0,0.0,0\r\n353962,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n353962,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n353962,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n353962,184,656,145,3462.0,1111,2,6.0,0.0,0\r\n353962,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n353962,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n319670,175,1181,4760,247.0,1111,0,2.0,1.0,0\r\n319670,175,1181,4760,247.0,1111,0,2.0,1.0,0\r\n319670,175,1181,4760,247.0,1111,2,2.0,1.0,0\r\n210578,279,898,3323,683.0,1111,0,3.0,1.0,0\r\n210578,279,898,3323,683.0,1111,0,3.0,1.0,0\r\n210578,279,898,3323,683.0,1111,0,3.0,1.0,0\r\n101110,281,1130,246,5380.0,1111,2,4.0,0.0,0\r\n101110,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n101110,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n101110,281,1130,246,5380.0,1111,0,4.0,0.0,0\r\n149798,224,614,4955,7924.0,1108,0,2.0,0.0,0\r\n6018,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n6018,184,656,145,3462.0,1111,0,6.0,0.0,0\r\n281262,279,898,3323,683.0,1109,0,4.0,1.0,0\r\n314519,219,349,1943,6208.0,1111,2,2.0,1.0, ...
