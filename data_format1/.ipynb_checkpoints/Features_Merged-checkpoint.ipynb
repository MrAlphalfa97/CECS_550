# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# # Load Profiles

# %%
df = pd.read_csv("./use_data/expanded_training.csv")
df_user = pd.read_csv("./use_data/profiles/user_profile.csv")
df_merchant = pd.read_csv("./use_data/profiles/merchant_profile.csv")
df_brand = pd.read_csv("./use_data/profiles/brand_profile.csv")
df_item = pd.read_csv("./use_data/profiles/item_profile.csv")
df_cat = pd.read_csv("./use_data/profiles/category_profile.csv")

# %% [markdown]
# # Merge Profiles

# %%
df_features = df

# %%
df_user.drop('user_id',axis=1,inplace=True)
df_features = pd.concat([df_features, df_user])
df_features
# Out:
#       user_id  item_id  cat_id  seller_id  brand_id  time_stamp  action_type  \
# 0    379824.0    198.0   656.0      145.0    3462.0      1111.0          0.0
# 1    379824.0    198.0   656.0      145.0    3462.0      1111.0          0.0
# 2    379824.0    198.0   656.0      145.0    3462.0      1111.0          2.0
# 3    379824.0    198.0   656.0      145.0    3462.0      1110.0          0.0
# 4    379824.0    198.0   656.0      145.0    3462.0      1110.0          0.0
# ..        ...      ...     ...        ...       ...         ...          ...
# 380       NaN      NaN     NaN        NaN       NaN         NaN          NaN
# 381       NaN      NaN     NaN        NaN       NaN         NaN          NaN
# 382       NaN      NaN     NaN        NaN       NaN         NaN          NaN
# 383       NaN      NaN     NaN        NaN       NaN         NaN          NaN
# 384       NaN      NaN     NaN        NaN       NaN         NaN          NaN
#
#      age_range  gender  label  ...  % repeat buyer gender  % repeat buyer age  \
# 0          5.0     1.0    0.0  ...                    NaN                 NaN
# 1          5.0     1.0    0.0  ...                    NaN                 NaN
# 2          5.0     1.0    0.0  ...                    NaN                 NaN
# 3          5.0     1.0    0.0  ...                    NaN                 NaN
# 4          5.0     1.0    0.0  ...                    NaN                 NaN
# ..         ...     ...    ...  ...                    ...                 ...
# 380        NaN     NaN    NaN  ...                   0.27                0.73
# 381        NaN     NaN    NaN  ...                   0.27                0.73
# 382        NaN     NaN    NaN  ...                   0.27                0.73
# 383        NaN     NaN    NaN  ...                   0.27                0.00
# 384        NaN     NaN    NaN  ...                   0.27                0.00
#
#      month   day  user_monthly_action_count  month_total_action_count  \
# 0      NaN   NaN                        NaN                       NaN
# 1      NaN   NaN                        NaN                       NaN
# 2      NaN   NaN                        NaN                       NaN
# 3      NaN   NaN                        NaN                       NaN
# 4      NaN   NaN                        NaN                       NaN
# ..     ...   ...                        ...                       ...
# 380   11.0   9.0                        3.0                     362.0
# 381   11.0   8.0                        3.0                     362.0
# 382   11.0   8.0                        3.0                     362.0
# 383   11.0  11.0                        1.0                     362.0
# 384   11.0  10.0                        1.0                     362.0
#
#      monthly_action_count_ratio  monthly_mean_action_type  user_buys  \
# 0                           NaN                       NaN        NaN
# 1                           NaN                       NaN        NaN
# 2                           NaN                       NaN        NaN
# 3                           NaN                       NaN        NaN
# 4                           NaN                       NaN        NaN
# ..                          ...                       ...        ...
# 380                    0.008287                       0.0        0.0
# 381                    0.008287                       0.0        0.0
# 382                    0.008287                       0.0        0.0
# 383                    0.002762                       0.0        0.0
# 384                    0.002762                       0.0        0.0
#
#      user_buy_ratio
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 380             0.0
# 381             0.0
# 382             0.0
# 383             0.0
# 384             0.0
#
# [770 rows x 33 columns]
