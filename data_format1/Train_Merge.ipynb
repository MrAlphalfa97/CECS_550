# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("./use_data/expanded_training.csv")
df_user = pd.read_csv("./use_data/profiles/user_profile.csv")
df_merchant = pd.read_csv("./use_data/profiles/merchant_profile.csv")
df_brand = pd.read_csv("./use_data/profiles/brand_profile.csv")
df_item = pd.read_csv("./use_data/profiles/item_profile.csv")
df_cat = pd.read_csv("./use_data/profiles/category_profile.csv")

# %% [markdown]
# # Merging Profiles

# %% [markdown]
# # Merge Merchant Profile

# %%
df_merchant
# Out:
#      seller_id  merchant action count  merchant action count ratio  \
# 0          145                     36                     0.093506
# 1          145                     36                     0.093506
# 2          145                     36                     0.093506
# 3          145                     36                     0.093506
# 4          145                     36                     0.093506
# ..         ...                    ...                          ...
# 380       4760                    105                     0.272727
# 381       4760                    105                     0.272727
# 382       4760                    105                     0.272727
# 383       3263                     18                     0.046753
# 384       4760                    105                     0.272727
#
#      merchant day count  merchant product diversity  \
# 0                     4                    0.038462
# 1                     4                    0.038462
# ...

# %%
df_merchant_group = df_merchant.groupby(['seller_id'])
# Out:
# /tmp/ipykernel_13240/2302865910.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_merchant_group = pd.DataFrame(df_merchant.groupby(['seller_id']))
#                  0
# count    26.000000
# mean   2609.192308
# std    1528.745447
# min     145.000000
# 25%    1291.500000
# 50%    2542.500000
# 75%    3812.500000
# max    4988.000000

# %%
df_merged_merchant = pd.merge(df, df_merchant_group, on=['seller_id'], how="left")
df_merged_merchant
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_merged_merchant = pd.merge(df, df_merchant_group, on=['seller_id'], how="left")
#       2 df_merged_merchant
#
# File ~/miniconda3/envs/patRec/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
# ...
